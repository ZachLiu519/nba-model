# %%
import pandas as pd
import numpy as np
import datascience as ds
import seaborn as sns

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#import all dataframes
nineteen_eighty_four = pd.read_csv("1984_advanced_stats.csv")
nineteen_eighty_five = pd.read_csv("1985_advanced_stats.csv")
nineteen_eighty_six = pd.read_csv("1986_advanced_stats.csv")
nineteen_eighty_seven = pd.read_csv("1987_advanced_stats.csv")
nineteen_eighty_eight = pd.read_csv("1988_advanced_stats.csv")
nineteen_eighty_nine = pd.read_csv("1989_advanced_stats.csv")
nineteen_ninety = pd.read_csv("1990_advanced_stats.csv")
nineteen_ninety_one = pd.read_csv("1991_advanced_stats.csv")
nineteen_ninety_two = pd.read_csv("1992_advanced_stats.csv")
nineteen_ninety_three = pd.read_csv("1993_advanced_stats.csv")
nineteen_ninety_four = pd.read_csv("1994_advanced_stats.csv")
nineteen_ninety_five = pd.read_csv("1995_advanced_stats.csv")
nineteen_ninety_six = pd.read_csv("1996_advanced_stats.csv")
nineteen_ninety_seven = pd.read_csv("1997_advanced_stats.csv")
nineteen_ninety_eight = pd.read_csv("1998_advanced_stats.csv")
nineteen_ninety_nine = pd.read_csv("1999_advanced_stats.csv")
two_thousand = pd.read_csv("2000_advanced_stats.csv")
two_thousand_one = pd.read_csv("2001_advanced_stats.csv")
two_thousand_two = pd.read_csv("2002_advanced_stats.csv")
two_thousand_three = pd.read_csv("2003_advanced_stats.csv")
two_thousand_four = pd.read_csv("2004_advanced_stats.csv")
two_thousand_five = pd.read_csv("2005_advanced_stats.csv")
two_thousand_six = pd.read_csv("2006_advanced_stats.csv")
two_thousand_seven = pd.read_csv("2007_advanced_stats.csv")
two_thousand_eight = pd.read_csv("2008_advanced_stats.csv")
two_thousand_nine = pd.read_csv("2009_advanced_stats.csv")
two_thousand_ten = pd.read_csv("2010_advanced_stats.csv")
two_thousand_eleven = pd.read_csv("2011_advanced_stats.csv")
two_thousand_twelve = pd.read_csv("2012_advanced_stats.csv")
two_thousand_thirteen = pd.read_csv("2013_advanced_stats.csv")
two_thousand_fourteen = pd.read_csv("2014_advanced_stats.csv")
two_thousand_fifteen = pd.read_csv("2015_advanced_stats.csv")
two_thousand_sixteen = pd.read_csv("2016_advanced_stats.csv")
two_thousand_seventeen = pd.read_csv("2017_advanced_stats.csv")
two_thousand_eighteen = pd.read_csv("2018_advanced_stats.csv")
two_thousand_nineteen = pd.read_csv("2019_advanced_stats.csv")

salaries = pd.read_excel("salaries_1985to2020_final.xlsx")
stats = pd.read_excel("all_seasons_advanced_stats.xlsx")

# %%
#isolate salaries by year and drop unnecessary columns
nineteen_eighty_four_salaries = salaries.loc[salaries['season_start'] == 1984].drop(columns = ['season', 'team', 'season_start', 'season_end', 'names'])
nineteen_eighty_five_salaries = salaries.loc[salaries['season_start'] == 1985].drop(columns = ['season', 'team', 'season_start', 'season_end', 'names'])
nineteen_eighty_six_salaries = salaries.loc[salaries['season_start'] == 1986].drop(columns = ['season', 'team', 'season_start', 'season_end', 'names'])
nineteen_eighty_seven_salaries = salaries.loc[salaries['season_start'] == 1987].drop(columns = ['season', 'team', 'season_start', 'season_end', 'names'])
nineteen_eighty_eight_salaries = salaries.loc[salaries['season_start'] == 1988].drop(columns = ['season', 'team', 'season_start', 'season_end', 'names'])
nineteen_eighty_nine_salaries = salaries.loc[salaries['season_start'] == 1989].drop(columns = ['season', 'team', 'season_start', 'season_end', 'names'])
nineteen_ninety_salaries = salaries.loc[salaries['season_start'] == 1990].drop(columns = ['season', 'team', 'season_start', 'season_end', 'names'])
nineteen_ninety_nine_salaries = salaries.loc[salaries['season_start'] == 1991].drop(columns = ['season', 'team', 'season_start', 'season_end', 'names'])
nineteen_ninety_two_salaries = salaries.loc[salaries['season_start'] == 1992].drop(columns = ['season', 'team', 'season_start', 'season_end', 'names'])
nineteen_ninety_three_salaries = salaries.loc[salaries['season_start'] == 1993].drop(columns = ['season', 'team', 'season_start', 'season_end', 'names'])
nineteen_ninety_four_salaries = salaries.loc[salaries['season_start'] == 1994].drop(columns = ['season', 'team', 'season_start', 'season_end', 'names'])
nineteen_ninety_five_salaries = salaries.loc[salaries['season_start'] == 1995].drop(columns = ['season', 'team', 'season_start', 'season_end', 'names'])
nineteen_ninety_six_salaries = salaries.loc[salaries['season_start'] == 1996].drop(columns = ['season', 'team', 'season_start', 'season_end', 'names'])
nineteen_ninety_seven_salaries = salaries.loc[salaries['season_start'] == 1997].drop(columns = ['season', 'team', 'season_start', 'season_end', 'names'])
nineteen_ninety_eight_salaries = salaries.loc[salaries['season_start'] == 1998].drop(columns = ['season', 'team', 'season_start', 'season_end', 'names'])
nineteen_ninety_nine_salaries = salaries.loc[salaries['season_start'] == 1999].drop(columns = ['season', 'team', 'season_start', 'season_end', 'names'])
two_thousand_salaries = salaries.loc[salaries['season_start'] == 2000].drop(columns = ['season', 'team', 'season_start', 'season_end', 'names'])
two_thousand_one_salaries = salaries.loc[salaries['season_start'] == 2001].drop(columns = ['season', 'team', 'season_start', 'season_end', 'names'])
two_thousand_two_salaries = salaries.loc[salaries['season_start'] == 2002].drop(columns = ['season', 'team', 'season_start', 'season_end', 'names'])
two_thousand_three_salaries = salaries.loc[salaries['season_start'] == 2003].drop(columns = ['season', 'team', 'season_start', 'season_end', 'names'])
two_thousand_four_salaries = salaries.loc[salaries['season_start'] == 2004].drop(columns = ['season', 'team', 'season_start', 'season_end', 'names'])
two_thousand_five_salaries = salaries.loc[salaries['season_start'] == 2005].drop(columns = ['season', 'team', 'season_start', 'season_end', 'names'])
two_thousand_six_salaries = salaries.loc[salaries['season_start'] == 2006].drop(columns = ['season', 'team', 'season_start', 'season_end', 'names'])
two_thousand_seven_salaries = salaries.loc[salaries['season_start'] == 2007].drop(columns = ['season', 'team', 'season_start', 'season_end', 'names'])
two_thousand_eight_salaries = salaries.loc[salaries['season_start'] == 2008].drop(columns = ['season', 'team', 'season_start', 'season_end', 'names'])
two_thousand_nine_salaries = salaries.loc[salaries['season_start'] == 2009].drop(columns = ['season', 'team', 'season_start', 'season_end', 'names'])
two_thousand_ten_salaries = salaries.loc[salaries['season_start'] == 2010].drop(columns = ['season', 'team', 'season_start', 'season_end', 'names'])
two_thousand_eleven_salaries = salaries.loc[salaries['season_start'] == 2011].drop(columns = ['season', 'team', 'season_start', 'season_end', 'names'])
two_thousand_twelve_salaries = salaries.loc[salaries['season_start'] == 2012].drop(columns = ['season', 'team', 'season_start', 'season_end', 'names'])
two_thousand_thirteen_salaries = salaries.loc[salaries['season_start'] == 2013].drop(columns = ['season', 'team', 'season_start', 'season_end', 'names'])
two_thousand_fourteen_salaries = salaries.loc[salaries['season_start'] == 2014].drop(columns = ['season', 'team', 'season_start', 'season_end', 'names'])
two_thousand_fifteen_salaries = salaries.loc[salaries['season_start'] == 2015].drop(columns = ['season', 'team', 'season_start', 'season_end', 'names'])
two_thousand_sixteen_salaries = salaries.loc[salaries['season_start'] == 2016].drop(columns = ['season', 'team', 'season_start', 'season_end', 'names'])
two_thousand_seventeen_salaries = salaries.loc[salaries['season_start'] == 2017].drop(columns = ['season', 'team', 'season_start', 'season_end', 'names'])
two_thousand_eighteen_salaries = salaries.loc[salaries['season_start'] == 2018].drop(columns = ['season', 'team', 'season_start', 'season_end', 'names'])
two_thousand_nineteen_salaries = salaries.loc[salaries['season_start'] == 2019].drop(columns = ['season', 'team', 'season_start', 'season_end', 'names'])

# %%
two_thousand_nineteen = two_thousand_nineteen.set_index("slug").join(two_thousand_nineteen_salaries.set_index('player_id')).dropna()

# %%
def standardize(df, column):
    series = []
    for i in df[column]:
        series.append((i - df[column].mean())/df[column].std())
    return series

def correlation(df, column_1, column_2):
    return np.mean(df[column_1] * df[column_2])

def scatter_and_correlation(df, column_1, column_2):
    df[column_1 + "_standard"] = standardize(df, column_1)
    df[column_2 + "_standard"] = standardize(df, column_2)
    df.plot.scatter(x = column_1 + "_standard", y = column_2 + '_standard')
    return correlation(df, column_1 + '_standard', column_2 + '_standard')

# %%
scatter_and_correlation(two_thousand_nineteen, 'age', 'salary')
# Out:
# 0.20701366752912712

# %%
scatter_and_correlation(two_thousand_nineteen, 'games_played', 'salary')
# Out:
# 0.316707578162372

# %%
scatter_and_correlation(two_thousand_nineteen, 'minutes_played', 'salary')
# Out:
# 0.5396557277763571

# %%
scatter_and_correlation(two_thousand_nineteen, 'assist_percentage', 'salary')
# Out:
# 0.37992927307965985

# %%
scatter_and_correlation(two_thousand_nineteen, 'box_plus_minus', 'salary')
# Out:
# 0.5253655203057234

# %%
scatter_and_correlation(two_thousand_nineteen, 'value_over_replacement_player', 'salary')
# Out:
# 0.6779314058291301

# %%
scatter_and_correlation(two_thousand_nineteen, 'win_shares', 'salary')
# Out:
# 0.6209373862567051

# %%
scatter_and_correlation(two_thousand_nineteen, 'total_rebound_percentage', 'salary')
# Out:
# 0.1094794758357308

# %%
scatter_and_correlation(two_thousand_nineteen, 'usage_percentage', 'salary')
# Out:
# 0.49671379085439327

# %%
scatter_and_correlation(two_thousand_nineteen, 'true_shooting_percentage', 'salary')
# Out:
# 0.23187963101539205
